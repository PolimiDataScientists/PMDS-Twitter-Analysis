# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
sentiments = pd.read_csv("../../data/sentiments.csv")
sentiments = sentiments[["day","negPercentage","netPercentage","posPercentage"]]

# %%
covidData = pd.read_csv("../../data/covidDataUS.csv")
covidData = covidData[["date","deathIncrease","positiveIncrease"]]
covidData.head()
# Out:
#          date  deathIncrease  positiveIncrease
# 0  2021-03-07            842             41835
# 1  2021-03-06           1680             60015
# 2  2021-03-05           2221             68787
# 3  2021-03-04           1743             65487
# 4  2021-03-03           2449             66836

# %%
start_date = '2020-05-01'
end_date = '2020-05-30'
mask = (covidData['date'] >= start_date) & (covidData['date'] <= end_date)
covidData = covidData.loc[mask]
covidData = covidData.sort_values(by=['date'])

# %%
sentiments.head()
# Out:
#           day  negPercentage  netPercentage  posPercentage
# 0  2020-05-01       0.202899       0.498551       0.298551
# 1  2020-05-02       0.199336       0.445183       0.355482
# 2  2020-05-03       0.230769       0.457692       0.311538
# 3  2020-05-04       0.180723       0.451807       0.367470
# 4  2020-05-05       0.226316       0.410526       0.363158

# %%
covidData.sort_values(by=['date'])
# Out:
#            date  deathIncrease  positiveIncrease
# 310  2020-05-01           1812             32880
# 309  2020-05-02           1521             29151
# 308  2020-05-03           1247             25759
# 307  2020-05-04            983             22106
# 306  2020-05-05           2496             22392
# 305  2020-05-06           1931             25312
# 304  2020-05-07           2732             27228
# 303  2020-05-08           1788             27198
# 302  2020-05-09           1459             25280
# 301  2020-05-10           1027             21112
# 300  2020-05-11            889             18080
# 299  2020-05-12           1518             22521
# 298  2020-05-13           1729             21481
# 297  2020-05-14           1846             26796
# 296  2020-05-15           1537             25407
# 295  2020-05-16           1249             23835
# 294  2020-05-17            862             20384
# 293  2020-05-18            853             20613
# ...

# %%
sentiments.plot('day', "negPercentage")
covidData.plot("date", "deathIncrease")
covidData.plot("date", "positiveIncrease")
# Out:
# <AxesSubplot:xlabel='date'>
