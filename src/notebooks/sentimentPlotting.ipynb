# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from analysis.SentimentAnalysis.sentimentAnalysis import SentimentAnalysis

# %%
sentimentAnalysis = SentimentAnalysis("../../data/tweets.csv")

# %%
sentimentAnalysis.compute_sentiment_per_day()

# %%
sentimentAnalysis.getSentimentStatistics()
# Out:
# day              2020-05-01
# negPercentage    2020-05-29
# netPercentage    2020-05-20
# posPercentage    2020-05-07
# dtype: object

# %%
covidData = pd.read_csv("../../data/covidDataUS.csv")
covidData = covidData[["date","deathIncrease","positiveIncrease"]]
covidData.head()

# %%
start_date = '2020-05-01'
end_date = '2020-05-30'
mask = (covidData['date'] >= start_date) & (covidData['date'] <= end_date)
covidData = covidData.loc[mask]
covidData = covidData.sort_values(by=['date'])

# %%
sentiments.head()

# %%
covidData.sort_values(by=['date'])

# %%
sentiments.plot('day', "negPercentage")
covidData.plot("date", "deathIncrease")
covidData.plot("date", "positiveIncrease")

# %%
sentiments = pd.read_csv("../../data/sentimentsUS.csv")

# %%
sentiments.head(40)
# Out:
#            day  timestamp  date  lang  text  day.1  text_modified  sentiment  \
# 0   2020-02-11          1     1     1     1      1              1          1
# 1   2020-02-12          1     1     1     1      1              1          1
# 2   2020-02-13          3     3     3     3      3              3          3
# 3   2020-02-14          1     1     1     1      1              1          1
# 4   2020-02-15          1     1     1     1      1              1          1
# 5   2020-02-17          2     2     2     2      2              2          2
# 6   2020-02-18          1     1     1     1      1              1          1
# 7   2020-02-19          4     4     4     4      4              4          4
# 8   2020-02-20          2     2     2     2      2              2          2
# 9   2020-02-21          5     5     5     5      5              5          5
# 10  2020-02-22         12    12    12    12     12             12         12
# 11  2020-02-23          8     8     8     8      8              8          8
# 12  2020-02-24          9     9     9     9      9              9          9
# 13  2020-02-25         13    13    13    13     13             13         13
# 14  2020-02-26         10    10    10    10     10             10         10
# 15  2020-02-27         13    13    13    13     13             13         13
# 16  2020-02-28         12    12    12    12     12             12         12
# 17  2020-02-29         42    42    42    42     42             42         42
# 18  2020-03-01         99    99    99    99     99             99         99
# 19  2020-03-02         96    96    96    96     96             96         96
# 20  2020-03-03         33    33    33    33     33             33         33
# 21  2020-03-04         61    61    61    61     61             61         61
# 22  2020-03-05         41    41    41    41     41             41         41
# 23  2020-03-06         93    93    93    93     93             93         93
# 24  2020-03-07         68    68    68    68     68             68         68
# 25  2020-03-08         70    70    70    70     70             70         70
# 26  2020-03-09         93    93    93    93     93             93         93
# 27  2020-03-10         93    93    93    93     93             93         93
# 28  2020-03-11         96    96    96    96     96             96         96
# 29  2020-03-12        337   337   337   337    337            337        337
# 30  2020-03-13        448   448   448   448    448            448        448
# 31  2020-03-14        334   334   334   334    334            334        334
# 32  2020-03-15        258   258   258   258    258            258        258
# 33  2020-03-16        292   292   292   292    292            292        292
# 34  2020-03-17        338   338   338   338    338            338        338
# 35  2020-03-18        393   393   393   393    393            393        393
# 36  2020-03-19        468   468   468   468    468            468        468
# 37  2020-03-20        496   496   496   496    496            496        496
# 38  2020-03-21        360   360   360   360    360            360        360
# 39  2020-03-22        253   253   253   253    253            253        253
#
#     negPercentage  netPercentage  posPercentage
# 0             NaN       1.000000            NaN
# 1        1.000000            NaN            NaN
# 2        0.333333       0.333333       0.333333
# 3        1.000000            NaN            NaN
# 4             NaN       1.000000            NaN
# 5        0.500000       0.500000            NaN
# 6             NaN            NaN       1.000000
# 7        0.250000       0.500000       0.250000
# 8             NaN       1.000000            NaN
# 9             NaN       0.600000       0.400000
# 10       0.083333       0.750000       0.166667
# 11       0.125000       0.750000       0.125000
# 12       0.333333       0.444444       0.222222
# 13       0.307692       0.538462       0.153846
# 14       0.500000       0.200000       0.300000
# 15       0.538462       0.307692       0.153846
# 16       0.166667       0.583333       0.250000
# 17       0.357143       0.523810       0.119048
# 18       0.292929       0.424242       0.282828
# 19       0.239583       0.541667       0.218750
# 20       0.272727       0.575758       0.151515
# 21       0.229508       0.573770       0.196721
# 22       0.170732       0.682927       0.146341
# 23       0.225806       0.559140       0.215054
# 24       0.235294       0.470588       0.294118
# 25       0.285714       0.385714       0.328571
# 26       0.150538       0.645161       0.204301
# 27       0.225806       0.559140       0.215054
# 28       0.239583       0.552083       0.208333
# 29       0.207715       0.531157       0.261128
# 30       0.252232       0.486607       0.261161
# 31       0.239521       0.500000       0.260479
# 32       0.189922       0.503876       0.306202
# 33       0.246575       0.465753       0.287671
# 34       0.139053       0.594675       0.266272
# 35       0.175573       0.526718       0.297710
# 36       0.177350       0.431624       0.391026
# 37       0.187500       0.536290       0.276210
# 38       0.236111       0.455556       0.308333
# 39       0.201581       0.494071       0.304348
